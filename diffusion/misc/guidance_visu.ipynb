# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
from guidance_class import DDPMPL
from torchvision.transforms import transforms
from PIL import Image

hparams = {
    'lr': 1e-4,
    'weight_decay': 1e-5,
    'num_train_timesteps': 1000,
    'in_channels': 3,
    'out_channels': 3,
    'use_pre_trained': False
}
guidance_path = "/mnt/raid/home/ajarry/data/ultrasound.png"
model = DDPMPL(guidance_path=guidance_path, **hparams)

device = torch.device("cuda")

# Generate a sample
state_dict = torch.load("/mnt/raid/home/ajarry/data/outputs_monai/guidance_output/model.pth")
model.load_state_dict(state_dict, strict=False)
model = model.to(device)

shape = (1, 3, 256,256)  # Adjust based on model's requirements
# List to store generated samples
samples = []
# transform = transforms.Compose([
#             transforms.Resize((256, 256)),
#             transforms.ToTensor(),
#  ])
# image = Image.open(guidance_path).convert("RGB")

# image = transform(image).unsqueeze(0)
# Generate 8 samples
model.eval()
iter = 0
with torch.no_grad():
    for _ in range(8):
        iter+=1
        print(iter)
        # Generate a random sample
        noise = torch.randn(shape)
        noise = noise.to(device)
        sample = model(noise).cpu().squeeze()  # Generate image and move to CPU
        samples.append(sample)

# Plot the 8 samples in a 2x4 grid
fig, axes = plt.subplots(2, 4)
for i, ax in enumerate(axes.flat):
    # Transpose the sample to (H, W, C) and convert to numpy for plotting
    img = samples[i].numpy().transpose(1, 2, 0)
    ax.imshow(img)
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 46
#      44         noise = torch.randn(shape)
#      45         noise = noise.to(device)
# ---> 46         sample = model(noise).cpu().squeeze()  # Generate image and move to CPU
#      47         samples.append(sample)
#      49 # Plot the 8 samples in a 2x4 grid
#
# File ~/.conda/envs/difmod/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/data/guidance_class.py:118, in DDPMPL.forward(self, x, timesteps, context)
#     116 if timesteps is None:
#     117     self.scheduler.set_timesteps(num_inference_steps=self.hparams.num_train_timesteps)
# --> 118     return self.inferer.sample(
#     119         input_noise=noisy_image,
#     120         diffusion_model=self.model,
#     121         scheduler=self.scheduler,
#     122         verbose=False,
#     123     )
#     124 else:
#     125     self.scheduler.set_timesteps(num_inference_steps=timesteps.item() if isinstance(timesteps, torch.Tensor) else timesteps)
#
# File ~/.conda/envs/difmod/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/.conda/envs/difmod/lib/python3.10/site-packages/generative/inferers/inferer.py:132, in DiffusionInferer.sample(self, input_noise, diffusion_model, scheduler, save_intermediates, intermediate_steps, conditioning, mode, verbose, seg)
#     128     model_output = diffusion_model(
#     129         model_input, timesteps=torch.Tensor((t,)).to(input_noise.device), context=None
#     130     )
#     131 else:
# --> 132     model_output = diffusion_model(
#     133         image, timesteps=torch.Tensor((t,)).to(input_noise.device), context=conditioning
#     134     )
#     136 # 2. compute previous image: x_t -> x_t-1
#     137 image, _ = scheduler.step(model_output, t, image)
#
# File ~/.conda/envs/difmod/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.conda/envs/difmod/lib/python3.10/site-packages/generative/networks/nets/diffusion_model_unet.py:1912, in DiffusionModelUNet.forward(self, x, timesteps, context, class_labels, down_block_additional_residuals, mid_block_additional_residual)
#    1910 down_block_res_samples: list[torch.Tensor] = [h]
#    1911 for downsample_block in self.down_blocks:
# -> 1912     h, res_samples = downsample_block(hidden_states=h, temb=emb, context=context)
#    1913     for residual in res_samples:
#    1914         down_block_res_samples.append(residual)
#
# File ~/.conda/envs/difmod/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.conda/envs/difmod/lib/python3.10/site-packages/generative/networks/nets/diffusion_model_unet.py:778, in DownBlock.forward(***failed resolving arguments***)
#     775 output_states = []
#     777 for resnet in self.resnets:
# --> 778     hidden_states = resnet(hidden_states, temb)
#     779     output_states.append(hidden_states)
#     781 if self.downsampler is not None:
#
# File ~/.conda/envs/difmod/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.conda/envs/difmod/lib/python3.10/site-packages/generative/networks/nets/diffusion_model_unet.py:671, in ResnetBlock.forward(self, x, emb)
#     669 def forward(self, x: torch.Tensor, emb: torch.Tensor) -> torch.Tensor:
#     670     h = x
# --> 671     h = self.norm1(h)
#     672     h = self.nonlinearity(h)
#     674     if self.upsample is not None:
#
# File ~/.conda/envs/difmod/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/.conda/envs/difmod/lib/python3.10/site-packages/torch/nn/modules/normalization.py:273, in GroupNorm.forward(self, input)
#     272 def forward(self, input: Tensor) -> Tensor:
# --> 273     return F.group_norm(
#     274         input, self.num_groups, self.weight, self.bias, self.eps)
#
# File ~/.conda/envs/difmod/lib/python3.10/site-packages/torch/nn/functional.py:2530, in group_norm(input, num_groups, weight, bias, eps)
#    2528     raise RuntimeError(f"Expected at least 2 dimensions for input tensor but received {input.dim()}")
#    2529 _verify_batch_size([input.size(0) * input.size(1) // num_groups, num_groups] + list(input.size()[2:]))
# -> 2530 return torch.group_norm(input, num_groups, weight, bias, eps, torch.backends.cudnn.enabled)
#
# RuntimeError: Expected weight to be a vector of size equal to the number of channels in input, but got weight of shape [128] and input of shape [128, 256, 256]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
